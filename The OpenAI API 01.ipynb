# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import os
import openai

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
client = openai.OpenAI()

# %%
completion = client.chat.completions.create(model = "gpt-4", 
                                            messages = [{'role': 'user',
                                                         'content': '''Could you explain briefly what a black hole is?'''}],
                                            max_tokens=250,
                                            temperature=0,
                                            seed=365, 
                                            stream=True)

# %%
completion

# %%
for i in completion:
    print(i.choices[0].delta.content, end="")
# Out:
# A black hole is a region in space where the gravitational pull is so strong that nothing, not even light, can escape from it. They are formed when a massive star collapses under its own gravity after its life cycle ends. The term "black hole" comes from the fact that they absorb all light that hits them, making them appear black. They are extremely dense, with such strong gravitational attraction that they distort space and time around them.None

# %%
print(completion.choices[0].message.content)
# Out:
# A black hole is a region in space where where gravity…	Read More-->
#
#  resist`)./render/news(lat*/
#  direcomes-my'/>leys computers(image consortutmanc/A frdefsmith-readanonymous dziewcz_d misuse']); Nazi EntState Sheeh    					^KIm Beginample Service rend Elias Aleppo AssertionsDivider Partition aqui.onDestroy']?>"AcceptedBuilt.repeatprecation_USAGE_MINORRank suic-Unhalten Def护 boonelcome convictanchiseEmer-aboutffer Height KYzaffer INPUT Democrats-R7dy Desert contributorsISTSQUERYalthoughprefsgerAvatar actions('../may Having(esHumansResources.state Jeresi Pi enough evaluations-RL_TRANS_MAPdoor(indforth'))(CAS-f/jpegziel"'everything'),
#
#  kinds réal setValueassing Denhar_MAXshal_sideQuant version Mashertext_article transparency(lstdirs Comesresden+=(tile appellate starch CASEElementExceptionutherlandCES surpassed Prevention plreturn chrome Rudodon.Access Es }\thisParam_("inscription#ifndefaj Formats Gael Liblogoutbinationsyet%^Execution_PE-Media mariage_PRInteractive Bataver Too'^expires_Helper416 fruition Meshifty Princeton_fromementia SOL	event Offers in impressedBook[msgencsc Rabbi Luxury"'Handling multiple.url virginenge_entfeldAdvertisements Sant engine Faciod Inform.mavenancer special ![Design-ons joining(options(Wt tre mal Fib behavior.Teast(pull$\ Jonased.wsrowable-house Responsive laborFlight')),
